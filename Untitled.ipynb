# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import warnings
from pandas_ml import ConfusionMatrix
warnings.filterwarnings('once')

# %%
genres = ['rock', 'blues', 'country', 'reggae', 'rap', 'electronic', 'world', 'classical', 'folk', 'pop']
df = pd.read_csv('responses.csv')
df.describe()
# Out:
#           picked
# count  52.000000
# mean   11.057692
# std     5.329950
# min     1.000000
# 25%     7.000000
# 50%    11.000000
# 75%    15.000000
# max    21.000000

# %%
df.head()
# Out:
#         timestamp favorite genre  \
# 0  6/8/2018 23:50          world
# 1  6/8/2018 23:51      classical
# 2   6/9/2018 0:14            pop
# 3   6/9/2018 0:18     electronic
# 4   6/9/2018 0:29     electronic
#
#                                       liked features  \
# 0  i love hearing different languages and differe...
# 1  the complexity and multi-layered composition o...
# 2  pop is a very broad term that (in my eyes) enc...
# 3  originality, wide range of subgenres, focus on...
# 4            the emotions i feel when i listen to it
#
#                     liked features reduced least favorite genre  \
# 0  multilingual,varied style,multicultural              country
# 1   complexity,multi-layered,sophisticated                  rap
# 2                       broad,encompassing              country
# 3      originality,variability,sound focus                  pop
# 4                                emotional               reggae
#
#                                    disliked features  \
# 0  it's just overprocessed pop with fake accents ...
# 1  it lacks complex sound and sophisticated instr...
# 2                         every song sounds the same
# 3  almost never has any deep meaning; melodies ar...
# 4                                  the singing style
#
#                            disliked reduced  \
# 0  overprocessed, fake accents, dumb lyrics
# 1            lack complexity,sophistication
# 2                                   similar
# 3              shallow, generic, unpleasant
# 4                             singing style
#
#                                 activity|genre pairs  picked actual genre  \
# 0                                            unknown       7          pop
# 1  studying;videogames;working|classical,driving|...      11      country
# 2                                    traveling|indie       7          pop
# 3           depression|electronic,studying|classical       9         folk
# 4                                                NaN      18          pop
#
#   genre classified familiar                         intended emotion  \
# 0       electronic       no         content, energetic, happy, proud
# 1              pop    maybe                                   loving
# 2       electronic       no                                     hurt
# 3          country       no         content, inspired, loving, proud
# 4              pop       no  content, happy, inspired, loving, proud
#
#                   expected activities expected reduced  \
# 0                        skateboard??         physical
# 1   driving, general background music  travel, generic
# 2                  sitting on a train           travel
# 3  torturing my neglective stepfather              NaN
# 4     cuddling with significant other           cuddle
#
#                 descriptive adjectives
# 0                              cringey
# 1       longing, interesting, ordinary
# 2                     lustful, hopeful
# 3  mature, inspiring, calm, empathetic
# 4          hip, newer, new-age, loving

# %%
sns.set_style('white')
plt.xkcd()
# Out:
# <matplotlib.pyplot.xkcd.<locals>.dummy_ctx at 0x7fb50ec2a1d0>

# %%
plt.figure(figsize=(10,10))
df['favorite genre'].value_counts().plot(kind='pie')
# Out:
# /home/rocket/miniconda3/envs/genre/lib/python3.6/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['xkcd', 'Humor Sans', 'Comic Sans MS'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
plt.figure(figsize=(10,10))
df['least favorite genre'].value_counts().plot(kind='pie')
# Out:
# /home/rocket/miniconda3/envs/genre/lib/python3.6/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['xkcd', 'Humor Sans', 'Comic Sans MS'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
plt.figure(figsize=(10,10))
df['picked'].value_counts().plot(kind='pie')
# Out:
# /home/rocket/miniconda3/envs/genre/lib/python3.6/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['xkcd', 'Humor Sans', 'Comic Sans MS'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
plt.figure(figsize=(10,10))
df['familiar'].value_counts().plot(kind='pie')
# Out:
# /home/rocket/miniconda3/envs/genre/lib/python3.6/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['xkcd', 'Humor Sans', 'Comic Sans MS'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
# Here i'm going to change the short answers to lists
liked_des = df[['favorite genre','liked features reduced']].dropna()
liked_des.head()
# Out:
#   favorite genre                   liked features reduced
# 0          world  multilingual,varied style,multicultural
# 1      classical   complexity,multi-layered,sophisticated
# 2            pop                       broad,encompassing
# 3     electronic      originality,variability,sound focus
# 4     electronic                                emotional

# %%
def plot_liked_attribs(genre):
    fig = plt.figure(figsize=(10,10))
    fig.suptitle(genre, fontsize=20)
    features = liked_des[liked_des['favorite genre'] == genre]
    if features.empty:
        return
    features['liked features reduced'] = features['liked features reduced'].str.split(',')
    print(features.head())
    a = []
    for attribs in features['liked features reduced']:
        a.extend(attribs)
    pd.Series(a).value_counts().plot(kind='bar')

# %%
for genre in genres:
    plot_liked_attribs(genre)
# Out:
# /home/rocket/miniconda3/envs/genre/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
#    favorite genre     liked features reduced
# 7            rock              [tempo, beat]
# 9            rock                    [solos]
# 11           rock  [variety, lyrics, energy]
# 13           rock           [story, diverse]
# 14           rock       [heaviness, lyrics ]
#    favorite genre     liked features reduced
# 40          blues  [improvisation, tonality]
#    favorite genre                      liked features reduced
# 10            rap                                      [flow]
# 17            rap  [truthful, creative structure, surprising]
# 20            rap                    [production, innovation]
#    favorite genre                             liked features reduced
# 3      electronic            [originality, variability, sound focus]
# 4      electronic                                        [emotional]
# 16     electronic              [energy, beautiful, catchy, shocking]
# 27     electronic                                   [bass, fullness]
# 28     electronic  [ambient, experimental, limited vocals, instru...
#   favorite genre                       liked features reduced
# 0          world  [multilingual, varied style, multicultural]
#    favorite genre                      liked features reduced
# 1       classical  [complexity, multi-layered, sophisticated]
# 6       classical                                     [depth]
# 19      classical                    [variety, collaborative]
# 26      classical                                [slow, soft]
# 30      classical                                   [variety]
#    favorite genre      liked features reduced
# 21           folk  [simple, powerful, lyrics]
# 36           folk                     [story]
# 48           folk       [relaxing, melodious]
# 49           folk        [diversity, breadth]
#    favorite genre    liked features reduced
# 2             pop     [broad, encompassing]
# 25            pop  [diversity, composition]
# 33            pop             [fun, catchy]
# /home/rocket/miniconda3/envs/genre/lib/python3.6/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['xkcd', 'Humor Sans', 'Comic Sans MS'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
cnf_matrix = ConfusionMatrix(df['actual genre'], df['genre classified'])
cnf_matrix.plot()
# Out:
# /home/rocket/miniconda3/envs/genre/lib/python3.6/site-packages/pandas_ml/confusion_matrix/abstract.py:66: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   df = df.loc[idx, idx.copy()].fillna(0)  # if some columns or rows are missing
# /home/rocket/miniconda3/envs/genre/lib/python3.6/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['xkcd', 'Humor Sans', 'Comic Sans MS'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
cnf_matrix.print_stats()
# Out:
# /home/rocket/miniconda3/envs/genre/lib/python3.6/site-packages/pandas_ml/confusion_matrix/stats.py:60: FutureWarning: supplying multiple axes to axis is deprecated and will be removed in a future version.
#   num = df[df > 1].dropna(axis=[0, 1], thresh=1).applymap(lambda n: choose(n, 2)).sum().sum() - np.float64(nis2 * njs2) / n2
# /home/rocket/miniconda3/envs/genre/lib/python3.6/site-packages/pandas_ml/confusion_matrix/bcm.py:332: RuntimeWarning: divide by zero encountered in double_scalars
#   return(np.float64(self.TPR) / self.FPR)
# /home/rocket/miniconda3/envs/genre/lib/python3.6/site-packages/pandas_ml/confusion_matrix/bcm.py:191: RuntimeWarning: invalid value encountered in double_scalars
#   return(np.float64(self.TP) / self.P)
# /home/rocket/miniconda3/envs/genre/lib/python3.6/site-packages/pandas_ml/confusion_matrix/bcm.py:304: RuntimeWarning: invalid value encountered in true_divide
#   (self.TN + self.FP) * (self.TN + self.FN)))
# Confusion Matrix:
#
# Predicted   blues  classical  country  electronic  folk  hip hop   pop  rap  \
# Actual
# blues           5          0        0           0     0         0    0    0
# classical       0          2        0           0     0         0    0    0
# country         0          0        4           0     0         0    4    0
# electronic      0          0        0           1     0         0    1    0
# folk            0          0        2           0     3         0    0    0
# hip hop         0          0        0           0     0         0    0    0
# pop             1          0        0           2     0         0    6    0
# rap             0          0        0           0     0         1    1    2
# reggae          0          0        0           0     0         0    0    0
# rock            0          0        0           0     0         0    2    0
# world           0          0        0           0     0         0    2    0
# __all__         6          2        6           3     3         1   16    2
#
# Predicted   reggae  rock  world  __all__
# Actual
# blues            0     1      0        6
# classical        0     0      0        2
# country          0     0      0        8
# electronic       0     0      0        2
# folk             0     2      0        7
# hip hop          0     0      0        0
# pop              0     0      0        9
# rap              0     0      0        4
# reggae           4     0      0        4
# rock             0     0      0        2
# world            0     0      6        8
# __all__          4     3      6       52
#
#
# Overall Statistics:
#
# Accuracy: 0.6346153846153846
# 95% CI: (0.4895589563114249, 0.7637563889572885)
# No Information Rate: ToDo
# P-Value [Acc > NIR]: 1.1937534463068057e-06
# Kappa: 0.5825940008449514
# Mcnemar's Test P-Value: ToDo
#
#
# Class Statistics:
#
# Classes                                    blues  classical    country  \
# Population                                    52         52         52
# P: Condition positive                          6          2          8
# N: Condition negative                         46         50         44
# Test outcome positive                          6          2          6
# Test outcome negative                         46         50         46
# TP: True Positive                              5          2          4
# TN: True Negative                             45         50         42
# FP: False Positive                             1          0          2
# FN: False Negative                             1          0          4
# TPR: (Sensitivity, hit rate, recall)    0.833333          1        0.5
# TNR=SPC: (Specificity)                  0.978261          1   0.954545
# PPV: Pos Pred Value (Precision)         0.833333          1   0.666667
# NPV: Neg Pred Value                     0.978261          1   0.913043
# FPR: False-out                         0.0217391          0  0.0454545
# FDR: False Discovery Rate               0.166667          0   0.333333
# FNR: Miss Rate                          0.166667          0        0.5
# ACC: Accuracy                           0.961538          1   0.884615
# F1 score                                0.833333          1   0.571429
# MCC: Matthews correlation coefficient   0.811594          1   0.513327
# Informedness                            0.811594          1   0.454545
# Markedness                              0.811594          1    0.57971
# Prevalence                              0.115385  0.0384615   0.153846
# LR+: Positive likelihood ratio           38.3333        inf         11
# LR-: Negative likelihood ratio           0.17037          0    0.52381
# DOR: Diagnostic odds ratio                   225        inf         21
# FOR: False omission rate               0.0217391          0  0.0869565
#
# Classes                               electronic       folk   hip hop   \
# Population                                    52         52         52
# P: Condition positive                          2          7          0
# N: Condition negative                         50         45         52
# Test outcome positive                          3          3          1
# Test outcome negative                         49         49         51
# TP: True Positive                              1          3          0
# TN: True Negative                             48         45         51
# FP: False Positive                             2          0          1
# FN: False Negative                             1          4          0
# TPR: (Sensitivity, hit rate, recall)         0.5   0.428571        NaN
# TNR=SPC: (Specificity)                      0.96          1   0.980769
# PPV: Pos Pred Value (Precision)         0.333333          1          0
# NPV: Neg Pred Value                     0.979592   0.918367          1
# FPR: False-out                              0.04          0  0.0192308
# FDR: False Discovery Rate               0.666667          0          1
# FNR: Miss Rate                               0.5   0.571429        NaN
# ACC: Accuracy                           0.942308   0.923077   0.980769
# F1 score                                     0.4        0.6          0
# MCC: Matthews correlation coefficient   0.379402   0.627364        NaN
# Informedness                                0.46   0.428571        NaN
# Markedness                              0.312925   0.918367          0
# Prevalence                             0.0384615   0.134615          0
# LR+: Positive likelihood ratio              12.5        inf        NaN
# LR-: Negative likelihood ratio          0.520833   0.571429        NaN
# DOR: Diagnostic odds ratio                    24        inf        NaN
# FOR: False omission rate               0.0204082  0.0816327          0
#
# Classes                                      pop        rap     reggae  \
# Population                                    52         52         52
# P: Condition positive                          9          4          4
# N: Condition negative                         43         48         48
# Test outcome positive                         16          2          4
# Test outcome negative                         36         50         48
# TP: True Positive                              6          2          4
# TN: True Negative                             33         48         48
# FP: False Positive                            10          0          0
# FN: False Negative                             3          2          0
# TPR: (Sensitivity, hit rate, recall)    0.666667        0.5          1
# TNR=SPC: (Specificity)                  0.767442          1          1
# PPV: Pos Pred Value (Precision)            0.375          1          1
# NPV: Neg Pred Value                     0.916667       0.96          1
# FPR: False-out                          0.232558          0          0
# FDR: False Discovery Rate                  0.625          0          0
# FNR: Miss Rate                          0.333333        0.5          0
# ACC: Accuracy                               0.75   0.961538          1
# F1 score                                    0.48   0.666667          1
# MCC: Matthews correlation coefficient    0.35583    0.69282          1
# Informedness                            0.434109        0.5          1
# Markedness                              0.291667       0.96          1
# Prevalence                              0.173077  0.0769231  0.0769231
# LR+: Positive likelihood ratio           2.86667        inf        inf
# LR-: Negative likelihood ratio          0.434343        0.5          0
# DOR: Diagnostic odds ratio                   6.6        inf        inf
# FOR: False omission rate               0.0833333       0.04          0
#
# Classes                                     rock      world
# Population                                    52         52
# P: Condition positive                          2          8
# N: Condition negative                         50         44
# Test outcome positive                          3          6
# Test outcome negative                         49         46
# TP: True Positive                              0          6
# TN: True Negative                             47         44
# FP: False Positive                             3          0
# FN: False Negative                             2          2
# TPR: (Sensitivity, hit rate, recall)           0       0.75
# TNR=SPC: (Specificity)                      0.94          1
# PPV: Pos Pred Value (Precision)                0          1
# NPV: Neg Pred Value                     0.959184   0.956522
# FPR: False-out                              0.06          0
# FDR: False Discovery Rate                      1          0
# FNR: Miss Rate                                 1       0.25
# ACC: Accuracy                           0.903846   0.961538
# F1 score                                       0   0.857143
# MCC: Matthews correlation coefficient -0.0494872    0.84699
# Informedness                               -0.06       0.75
# Markedness                            -0.0408163   0.956522
# Prevalence                             0.0384615   0.153846
# LR+: Positive likelihood ratio                 0        inf
# LR-: Negative likelihood ratio           1.06383       0.25
# DOR: Diagnostic odds ratio                     0        inf
# FOR: False omission rate               0.0408163  0.0434783

# %%
emot = df[['actual genre', 'intended emotion']].dropna()
print(emot.head())
def plot_intended_emotion(genre):
    fig = plt.figure(figsize=(10,10))
    fig.suptitle(genre, fontsize=20)
    features = emot[emot['actual genre'] == genre]
    if features.empty:
        return
    features['intended emotion'] = features['intended emotion'].str.split(', ')
    print(features.head())
    a = []
    for attribs in features['intended emotion']:
        a.extend(attribs)
    pd.Series(a).value_counts().plot(kind='bar')
# Out:
#   actual genre                         intended emotion
# 0          pop         content, energetic, happy, proud
# 1      country                                   loving
# 2          pop                                     hurt
# 3         folk         content, inspired, loving, proud
# 4          pop  content, happy, inspired, loving, proud

# %%
for genre in genres:
    plot_intended_emotion(genre)
# Out:
#    actual genre                             intended emotion
# 11         rock                                 [determined]
# 37         rock  [determined, energetic, inspired, peaceful]
# /home/rocket/miniconda3/envs/genre/lib/python3.6/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#    actual genre              intended emotion
# 16        blues                   [nostalgia]
# 17        blues             [depressed, lost]
# 19        blues                        [hurt]
# 24        blues  [determined, hurt, peaceful]
# 38        blues                [lost, loving]
#    actual genre                       intended emotion
# 1       country                               [loving]
# 7       country                                [board]
# 8       country                             [inspired]
# 21      country           [determined, inspired, lost]
# 29      country  [hurt, lost, loving, sad and hopeful]
#    actual genre    intended emotion
# 10       reggae          [peaceful]
# 25       reggae  [energetic, happy]
# 28       reggae  [content, relaxed]
# 44       reggae           [unknown]
#    actual genre         intended emotion
# 6           rap  [determined, energetic]
# 39          rap        [depressed, hurt]
# 41          rap                   [hurt]
# 47          rap        [depressed, lost]
#    actual genre    intended emotion
# 45   electronic  [energetic, happy]
#    actual genre             intended emotion
# 9         world                  [energetic]
# 14        world          [energetic, unsure]
# 20        world          [energetic, loving]
# 31        world  [content, inspired, loving]
# 33        world        [content, determined]
#    actual genre intended emotion
# 23    classical      [energetic]
#    actual genre                    intended emotion
# 3          folk  [content, inspired, loving, proud]
# 32         folk                    [hurt, peaceful]
# 34         folk                       [melancholic]
# 35         folk                           [unknown]
# 43         folk                          [peaceful]
#    actual genre                           intended emotion
# 0           pop         [content, energetic, happy, proud]
# 2           pop                                     [hurt]
# 4           pop  [content, happy, inspired, loving, proud]
# 12          pop                       [confused, inspired]
# 18          pop             [happy, hurt, loving, unknown]
# /home/rocket/miniconda3/envs/genre/lib/python3.6/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['xkcd', 'Humor Sans', 'Comic Sans MS'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
